# %%
class MyLinearReg:
    def __init__(self) -> None:
        self.m = None
        self.n = None
    
    def fit(self, X_train,y_train):
        
        num = 0
        den = 0
        for i in range(X_train.shape[0]):

            num = num + ((X_train[i] - X_train.mean())) * (y_train[i] - y_train.mean())
            den = den + ((X_train[i] - X_train.mean())) * ((X_train[i] - X_train.mean()))

        self.m =  num / den
        self.b = y_train.mean() - self.m * X_train.mean()

        print(self.m)
        print(self.b)



    def predict(self, X_test):
        
        return self.m * X_test + self.b

# %%
import pandas as pd

# %%
df = pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  5.00     2.50
# 1  5.16     4.19
# 2  5.32     4.13
# 3  5.33     3.90
# 4  5.49     3.84

# %%
X = df.iloc[:, 0].values
y = df.iloc[:, 1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train , y_test = train_test_split(X, y, test_size=2, random_state=2)

# %%
X_train.shape
# Out:
# (98,)

# %%
lr = MyLinearReg()

# %%
lr.fit(X_train, y_train)
# Out:
# 1.171591380162133
# -2.5370718292215724

# %%
X_test[0]
# Out:
# np.float64(8.33)

# %%
print(lr.predict(X_test[0]))
# Out:
# 7.222284367528996

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train.reshape(-1, 1), y_train)

print("My slope:", lr.m)
print("Sklearn slope:", model.coef_[0])

print("My intercept:", lr.b)
print("Sklearn intercept:", model.intercept_)

print("My prediction:", lr.predict(X_test[0]))
print("Sklearn prediction:", model.predict([[X_test[0]]])[0])
# Out:
# My slope: 1.171591380162133
# Sklearn slope: 1.1715913801621332
# My intercept: -2.5370718292215724
# Sklearn intercept: -2.537071829221574
# My prediction: 7.222284367528996
# Sklearn prediction: 7.222284367528996
